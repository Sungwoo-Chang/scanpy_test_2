# %% [markdown]
# https://www.youtube.com/watch?v=Ee0PQUwVH8Q&t=496s

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import random

folder_path = "C:/Users/heung/OneDrive/Documents/scData/14. GSE136001_RAW/"

# %% [markdown]
# # Load data

# %%
# Load file
adata = sc.read(folder_path + "annotated.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 37255 × 16739
#     obs: 'sample', 'sex', 'condition', 'n_genes', 'total_counts', 'pct_counts_mito', 'pct_counts_ribo', '_scvi_batch', '_scvi_labels', 'leiden', '_scvi_raw_norm_scaling', 'cell_type'
#     var: 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'cell_type_colors', 'condition_colors', 'dendrogram_cell_type', 'leiden', 'leiden_colors', 'log1p', 'markers', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'scvi_markers', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs'
#     varm: 'PCs'
#     layers: 'counts', 'scvi_normalized'
#     obsp: 'connectivities', 'distances'

# %%
cell_subset = adata[adata.obs['cell_type'].isin(['Microglia', 'Activated microglia'])].copy()
cell_subset.obs.tail()
# Out:
#                          sample   sex condition  n_genes  total_counts  \
# TTTGTCAGTCATACTG-1    m-tumor-2  male     tumor      949        1681.0
# TTTGTCAGTGCGCTTG-1    m-tumor-2  male     tumor     1001        2119.0
# TTTGTCAGTTCACCTC-1    m-tumor-2  male     tumor     2293        6668.0
# TTTGTCATCCTATTCA-1-1  m-tumor-2  male     tumor      956        1857.0
# TTTGTCATCTGTTTGT-1    m-tumor-2  male     tumor      956        1783.0
#
#                       pct_counts_mito  pct_counts_ribo  _scvi_batch  \
# TTTGTCAGTCATACTG-1           2.260559         6.127306            0
# TTTGTCAGTGCGCTTG-1           1.557338         7.597923            0
# TTTGTCAGTTCACCTC-1           0.539892        10.662868            0
# TTTGTCATCCTATTCA-1-1         1.938611         6.946688            0
# TTTGTCATCTGTTTGT-1           1.682558         9.197981            0
#
#                       _scvi_labels leiden  _scvi_raw_norm_scaling  \
# TTTGTCAGTCATACTG-1               0      2                5.948840
# TTTGTCAGTGCGCTTG-1               0      3                4.719207
# TTTGTCAGTTCACCTC-1               0      7                1.499700
# TTTGTCATCCTATTCA-1-1             0      3                5.385029
# TTTGTCATCTGTTTGT-1               0      0                5.608525
#
#                                 cell_type
# TTTGTCAGTCATACTG-1              Microglia
# TTTGTCAGTGCGCTTG-1    Activated microglia
# TTTGTCAGTTCACCTC-1    Activated microglia
# TTTGTCATCCTATTCA-1-1  Activated microglia
# TTTGTCATCTGTTTGT-1              Microglia

# %%
cell_subset.obs.groupby(['condition', 'sample']).size()
# Out:
# C:\Users\heung\AppData\Local\Temp\ipykernel_51028\4129752716.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cell_subset.obs.groupby(['condition', 'sample']).size()
# condition  sample
# normal     f-ctrl-1     4544
#            f-ctrl-2     4219
#            f-tumor-1       0
#            f-tumor-2       0
#            m-ctrl-1     4136
#            m-ctrl-2     4472
#            m-tumor-1       0
#            m-tumor-2       0
# tumor      f-ctrl-1        0
#            f-ctrl-2        0
#            f-tumor-1    3051
#            f-tumor-2    3852
#            m-ctrl-1        0
#            m-ctrl-2        0
#            m-tumor-1    2316
#            m-tumor-2    3284
# dtype: int64

# %%
adata.X.max()
# Out:
# 8.663969

# %% [markdown]
# # Making pseudo bulk file

# %%
pbs = []
for sample in cell_subset.obs['sample'].unique():
    samp_cell_subset = cell_subset[cell_subset.obs['sample'] == sample]

    rep_adata = sc.AnnData(
        X = samp_cell_subset.X.sum(axis = 0),
        var = samp_cell_subset.var[[]])
    
    rep_adata.obs_names = [sample]
    rep_adata.obs['condition'] = samp_cell_subset.obs['condition'].iloc[0]
    
    pbs.append(rep_adata)

# %%
pb = sc.concat(pbs)
pb.obs
# Out:
#           condition
# f-ctrl-1     normal
# f-ctrl-2     normal
# f-tumor-1     tumor
# f-tumor-2     tumor
# m-ctrl-1     normal
# m-ctrl-2     normal
# m-tumor-1     tumor
# m-tumor-2     tumor

# %% [markdown]
# # Making 3 pseudo replicates per sample

# %%
pbs = []
for sample in cell_subset.obs['sample'].unique():
    samp_cell_subset = cell_subset[cell_subset.obs['sample'] == sample]

    # Splitting the cells into 3 random groups -> 3 pseudo replicates
    indices = list(samp_cell_subset.obs_names)
    random.shuffle(indices)
    indices = np.array_split(np.array(indices), 3)

    # Creating pseudo replicates
    for i, pseudo_rep in enumerate(indices):
        rep_adata = sc.AnnData(
            X = samp_cell_subset.X.sum(axis = 0),
            var = samp_cell_subset.var[[]])
        
        rep_adata.obs_names = [sample]
        rep_adata.obs['condition'] = samp_cell_subset.obs['condition'].iloc[0]
        rep_adata.obs['replicate'] = i
        
        pbs.append(rep_adata)

# %%
pb = sc.concat(pbs)
pb.obs
# Out:
# c:\Users\heung\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#           condition  replicate
# f-ctrl-1     normal          0
# f-ctrl-1     normal          1
# f-ctrl-1     normal          2
# f-ctrl-2     normal          0
# f-ctrl-2     normal          1
# f-ctrl-2     normal          2
# f-tumor-1     tumor          0
# f-tumor-1     tumor          1
# f-tumor-1     tumor          2
# f-tumor-2     tumor          0
# f-tumor-2     tumor          1
# f-tumor-2     tumor          2
# m-ctrl-1     normal          0
# m-ctrl-1     normal          1
# m-ctrl-1     normal          2
# m-ctrl-2     normal          0
# m-ctrl-2     normal          1
# m-ctrl-2     normal          2
# m-tumor-1     tumor          0
# m-tumor-1     tumor          1
# m-tumor-1     tumor          2
# m-tumor-2     tumor          0
# m-tumor-2     tumor          1
# m-tumor-2     tumor          2

# %% [markdown]
# # DEseq

# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
counts = pd.DataFrame(pb.X, columns = pb.var_names)
counts.head()
# Out:
#       Sox17      Mrpl15      Lypla1   Gm37988        Tcea1     Rgs20  \
# 0  0.000000  957.320618  748.307861  0.000000  1427.360352  3.597847
# 1  0.000000  871.911316  792.684204  0.000000  1360.673584  0.000000
# 2  0.000000  633.163513  480.285828  0.000000   890.045898  0.000000
# 3  0.000000  807.924072  640.462280  0.000000  1121.771973  1.145522
# 4  2.057444  851.843201  698.285278  1.444667  1256.575928  1.590821
#
#       Atp6v1h      Rb1cc1  4732440D04Rik  St18  ...  CR974586.5      Csprs  \
# 0  679.845032  752.281372      67.379410   0.0  ...    0.000000   0.000000
# 1  686.552246  766.941833      93.056030   0.0  ...    0.000000   1.422774
# 2  450.596313  411.495850      47.808067   0.0  ...    1.066726  11.447237
# 3  596.738953  535.628479      58.374336   0.0  ...    0.000000  15.097595
# 4  610.802917  720.442688      83.699104   0.0  ...    0.000000   0.000000
#
#    AC132444.6  AC125149.3  AC125149.2  AC168977.2  AC168977.1   AC149090.1  \
# 0    3.811548    3.604362    0.000000    0.000000    3.361282  5594.480957
# 1    0.000000    4.961704    0.000000    0.000000    1.544280  5647.447266
# 2    0.000000   33.003674    0.000000    0.866491    1.179816  2914.951172
# 3    0.000000   22.969788    0.000000    2.134902    2.604242  4165.076660
# 4    1.984241    3.674593    1.619757    0.000000    1.327301  4549.992188
#
#    CAAA01118383.1  CAAA01147332.1
# 0      523.530029       13.202333
# 1      520.149353       14.070037
# 2      327.008636        2.308375
# 3      448.633331        8.662447
# 4      433.150116       12.491718
#
# [5 rows x 16739 columns]

# %% [markdown]
# > **이하 오류남**

# %%
dds = DeseqDataSet(
    counts = counts,
    clinical = pb.obs,
    design_factors = 'condition'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 dds = DeseqDataSet(
#       2     counts = counts,
#       3     clinical = pb.obs,
#       4     design_factors = 'condition'
#       5 )
#
# TypeError: DeseqDataSet.__init__() got an unexpected keyword argument 'clinical'
